# %% [markdown]
# <a href="https://colab.research.google.com/github/allissonst/formacao-alura-gbtech-dados/blob/main/Pandas_formatos_diferentes_de_IO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando os alunos

# %%
import pandas as pd

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f")
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m")

# %%
nomes_f.sample(5)
# Out:
#          nome  regiao    freq  rank sexo
# 4     ADRIANA       0  565621     5    F
# 2   FRANCISCA       0  721637     3    F
# 7    FERNANDA       0  531607     8    F
# 18    VANESSA       0  417512    19    F
# 9       ALINE       0  509869    10    F

# %%
nomes_m.sample(10)
# Out:
#        nome  regiao     freq  rank sexo
# 14  MARCELO       0   690098    15    M
# 2   ANTONIO       0  2567494     3    M
# 13   DANIEL       0   706527    14    M
# 5     PAULO       0  1417907     6    M
# 17   FELIPE       0   615924    18    M
# 9    MARCOS       0  1101126    10    M
# 0      JOSE       0  5732508     1    M
# 10     LUIS       0   931530    11    M
# 4    CARLOS       0  1483121     5    M
# 11  GABRIEL       0   922744    12    M

# %%
print(f'Quantidade de nomes femininos: {len(nomes_f)}')
print(f'Quantidade de nomes masculinos: {len(nomes_m)}')
print(f'Quantidade de nomes: {len(nomes_f)+len(nomes_m)}')
# Out:
# Quantidade de nomes femininos: 20
# Quantidade de nomes masculinos: 20
# Quantidade de nomes: 40

# %%
frames = [nomes_f, nomes_m]
frames
# Out:
# [         nome  regiao      freq  rank sexo
#  0       MARIA       0  11694738     1    F
#  1         ANA       0   3079729     2    F
#  2   FRANCISCA       0    721637     3    F
#  3     ANTONIA       0    588783     4    F
#  4     ADRIANA       0    565621     5    F
#  5     JULIANA       0    562589     6    F
#  6      MARCIA       0    551855     7    F
#  7    FERNANDA       0    531607     8    F
#  8    PATRICIA       0    529446     9    F
#  9       ALINE       0    509869    10    F
#  10     SANDRA       0    479230    11    F
#  11     CAMILA       0    469851    12    F
#  12     AMANDA       0    464624    13    F
#  13      BRUNA       0    460770    14    F
#  14    JESSICA       0    456472    15    F
#  15    LETICIA       0    434056    16    F
#  16      JULIA       0    430067    17    F
#  17    LUCIANA       0    429769    18    F
#  18    VANESSA       0    417512    19    F
#  19    MARIANA       0    381778    20    F,
# ...

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes.sample(5)
# Out:
#        nome
# 4   ADRIANA
# 0     MARIA
# 13   DANIEL
# 15  LETICIA
# 11   CAMILA

# %% [markdown]
# # Colocando o ID dos alunos

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 40

# %%
nomes["id_aluno"] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno
# 8   PATRICIA        14
# 15     BRUNO        20
# 0       JOSE        26
# 11   GABRIEL        37
# 8       LUIZ        10

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes
# Out:
#          nome  id_aluno                 dominio
# 0       MARIA         7  @dominiodoemail.com.br
# 1         ANA        11     @servicodoemail.com
# 2   FRANCISCA        13     @servicodoemail.com
# 3     ANTONIA        39     @servicodoemail.com
# 4     ADRIANA         6  @dominiodoemail.com.br
# 5     JULIANA        12     @servicodoemail.com
# 6      MARCIA        24     @servicodoemail.com
# 7    FERNANDA         2  @dominiodoemail.com.br
# 8    PATRICIA        14  @dominiodoemail.com.br
# 9       ALINE        21     @servicodoemail.com
# 10     SANDRA         9     @servicodoemail.com
# 11     CAMILA        38  @dominiodoemail.com.br
# 12     AMANDA        25     @servicodoemail.com
# 13      BRUNA         8     @servicodoemail.com
# 14    JESSICA        19     @servicodoemail.com
# 15    LETICIA        40     @servicodoemail.com
# 16      JULIA         4     @servicodoemail.com
# 17    LUCIANA        32     @servicodoemail.com
# 18    VANESSA        22     @servicodoemail.com
# ...

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes
# Out:
#          nome  id_aluno                 dominio  \
# 0       MARIA         7  @dominiodoemail.com.br
# 1         ANA        11     @servicodoemail.com
# 2   FRANCISCA        13     @servicodoemail.com
# 3     ANTONIA        39     @servicodoemail.com
# 4     ADRIANA         6  @dominiodoemail.com.br
# 5     JULIANA        12     @servicodoemail.com
# 6      MARCIA        24     @servicodoemail.com
# 7    FERNANDA         2  @dominiodoemail.com.br
# 8    PATRICIA        14  @dominiodoemail.com.br
# 9       ALINE        21     @servicodoemail.com
# 10     SANDRA         9     @servicodoemail.com
# 11     CAMILA        38  @dominiodoemail.com.br
# 12     AMANDA        25     @servicodoemail.com
# 13      BRUNA         8     @servicodoemail.com
# 14    JESSICA        19     @servicodoemail.com
# 15    LETICIA        40     @servicodoemail.com
# 16      JULIA         4     @servicodoemail.com
# 17    LUCIANA        32     @servicodoemail.com
# ...

# %% [markdown]
# # Criando a tabela Cursos

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %% [markdown]
# #Alterando o Index de Cursos

# %%
cursos = cursos.rename(columns={'Nome do curso' : 'nome_do_curso'})

# %%
cursos.head(2)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web

# %%
cursos['id'] = cursos.index +1

# %%
cursos.head(5)
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head(5)
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# # Matriculando os alunos nos cursos

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio  \
# 18    VANESSA        22     @servicodoemail.com
# 11     CAMILA        38  @dominiodoemail.com.br
# 3   FRANCISCO        36     @servicodoemail.com
# 8    PATRICIA        14  @dominiodoemail.com.br
# 4      CARLOS        30  @dominiodoemail.com.br
#
#                              email  matriculas
# 18      vanessa@servicodoemail.com           1
# 11    camila@dominiodoemail.com.br           4
# 3     francisco@servicodoemail.com           2
# 8   patricia@dominiodoemail.com.br           2
# 4     carlos@dominiodoemail.com.br           1

# %%
nomes.matriculas.describe()
# Out:
# count    40.000000
# mean      2.025000
# std       1.329883
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       6.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.displot(nomes.matriculas)

# %%
nomes.matriculas.value_counts()
# Out:
# 1    18
# 2    13
# 4     4
# 3     3
# 6     2
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno                 dominio  \
# 2    ANTONIO        27     @servicodoemail.com
# 16     JULIA         4     @servicodoemail.com
# 1        ANA        11     @servicodoemail.com
# 8   PATRICIA        14  @dominiodoemail.com.br
# 9     MARCOS        16  @dominiodoemail.com.br
#
#                              email  matriculas
# 2       antonio@servicodoemail.com           1
# 16        julia@servicodoemail.com           1
# 1           ana@servicodoemail.com           4
# 8   patricia@dominiodoemail.com.br           2
# 9     marcos@dominiodoemail.com.br           2

# %% [markdown]
# # Selecionando Cursos

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno              dominio                       email  \
# 13    BRUNA         8  @servicodoemail.com    bruna@servicodoemail.com
# 2   ANTONIO        27  @servicodoemail.com  antonio@servicodoemail.com
# 19  RODRIGO         3  @servicodoemail.com  rodrigo@servicodoemail.com
#
#     matriculas
# 13           2
# 2            1
# 19           1

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])

# %%
matriculas
# Out:
#     id_aluno  id_curso
# 0          7         1
# 1          7        18
# 2         11         9
# 3         11        13
# 4         11         8
# ..       ...       ...
# 76        20         4
# 77        18         9
# 78        35        15
# 79        29        14
# 80         3         3
#
# [81 rows x 2 columns]

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                            1                Lógica de programação
# 3                           12                          C# para Web
# 4                            2                        Ruby on Rails
# 5                            2                     Cursos de Python
# 7                            1                        .NET para web
# 8                            3           Novas integrações com Java
# 9                            4                         TDD com Java
# 10                          10                  Código limpo com C#
# 11                           4  Preparatório para certificação Java
# 12                          12                      Hardware básico
# 13                           8                Persistência com .NET
# 14                          10                  Desenvolvendo jogos
# 15                           2                     Análise de dados
# ...

# %%
nomes.head()
# Out:
#         nome  id_aluno                 dominio                          email  \
# 0      MARIA         7  @dominiodoemail.com.br    maria@dominiodoemail.com.br
# 1        ANA        11     @servicodoemail.com         ana@servicodoemail.com
# 2  FRANCISCA        13     @servicodoemail.com   francisca@servicodoemail.com
# 3    ANTONIA        39     @servicodoemail.com     antonia@servicodoemail.com
# 4    ADRIANA         6  @dominiodoemail.com.br  adriana@dominiodoemail.com.br
#
#    matriculas
# 0           2
# 1           4
# 2           1
# 3           1
# 4           2

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0         7         1
# 1         7        18
# 2        11         9
# 3        11        13
# 4        11         8

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
matriculas_por_cursos = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
matriculas_por_cursos.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            1  Lógica de programação
# 3                           12            C# para Web
# 4                            2          Ruby on Rails
# 5                            2       Cursos de Python
# 7                            1          .NET para web

# %% [markdown]
# # Saída em diferentes formatos

# %%
matriculas_por_cursos.to_csv('matriculas_por_cursos.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-3848f1063ff5> in <module>()
# ----> 1 'matriculas_por_cursos.csv'('matriculas_por_cursos.csv', index = False)
#
# TypeError: 'str' object is not callable

# %%
pd.read_csv('matriculas_por_cursos.csv')
# Out:
#     quantidade_de_alunos                        nome_do_curso
# 0                      1                Lógica de programação
# 1                     12                          C# para Web
# 2                      2                        Ruby on Rails
# 3                      2                     Cursos de Python
# 4                      1                        .NET para web
# 5                      3           Novas integrações com Java
# 6                      4                         TDD com Java
# 7                     10                  Código limpo com C#
# 8                      4  Preparatório para certificação Java
# 9                     12                      Hardware básico
# 10                     8                Persistência com .NET
# 11                    10                  Desenvolvendo jogos
# 12                     2                     Análise de dados
# 13                     8                Programação funcional
# ...

# %%
matriculas_json = matriculas_por_cursos.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":1,"3":12,"4":2,"5":2,"7":1,"8":3,"9":4,"10":10,"11":4,"12":12,"13":8,"14":10,"15":2,"18":8,"20":2},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","7":".NET para web","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","11":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","18":"Programa\\u00e7\\u00e3o funcional","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_cursos.to_html()

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>12</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>3</td>
#       <td>Novas integrações com Java</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4</td>
#       <td>TDD com Java</td>
#     </tr>
#     <tr>
#       <th>10</th>
# ...

# %% [markdown]
# #Criando o banco SQL

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect # adicionando o método inspect

engine = create_engine('sqlite:///:memory:')
engine
type(engine)

matriculas_por_cursos.to_sql('matriculas', engine)

inspector = inspect(engine) # criando um Inspector object
print(inspector.get_table_names()) # Exibindo as tabelas com o inspecto
# Out:
# ['matriculas']

# %% [markdown]
# #Buscando do banco SQL

# %%
query = 'select * from matriculas where quantidade_de_alunos > 10'

# %%
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos    nome_do_curso
# 0         3                    12      C# para Web
# 1        12                    12  Hardware básico

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                     1
# 1                           C# para Web                    12
# 2                         Ruby on Rails                     2
# 3                      Cursos de Python                     2
# 4                         .NET para web                     1
# 5            Novas integrações com Java                     3
# 6                          TDD com Java                     4
# 7                   Código limpo com C#                    10
# 8   Preparatório para certificação Java                     4
# 9                       Hardware básico                    12
# 10                Persistência com .NET                     8
# 11                  Desenvolvendo jogos                    10
# 12                     Análise de dados                     2
# 13                Programação funcional                     8
# ...

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 10')

# %%
muitas_matriculas
# Out:
#      nome_do_curso  quantidade_de_alunos
# 1      C# para Web                    12
# 9  Hardware básico                    12

# %% [markdown]
# # Escrevendo no banco

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Nomes dos alunos e alunas da próxima turma

# %%
matriculas_por_cursos.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            1  Lógica de programação
# 3                           12            C# para Web
# 4                            2          Ruby on Rails
# 5                            2       Cursos de Python
# 7                            1          .NET para web

# %%
matriculas
# Out:
#     id_aluno  id_curso
# 0          7         1
# 1          7        18
# 2         11         9
# 3         11        13
# 4         11         8
# ..       ...       ...
# 76        20         4
# 77        18         9
# 78        35        15
# 79        29        14
# 80         3         3
#
# [81 rows x 2 columns]

# %%
id_curso = 5
proxima_turma =  matriculas.query("id_curso == {}".format(id_curso))
proxima_turma
# Out:
#     id_aluno  id_curso
# 59        31         5
# 64        33         5

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 0     MARIA         7  @dominiodoemail.com.br   maria@dominiodoemail.com.br
# 11   CAMILA        38  @dominiodoemail.com.br  camila@dominiodoemail.com.br
# 15  LETICIA        40     @servicodoemail.com    leticia@servicodoemail.com
#
#     matriculas
# 0            2
# 11           4
# 15           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso    nome                 dominio  \
# id_aluno
# 31               5    LUIS  @dominiodoemail.com.br
# 33               5  RAFAEL     @servicodoemail.com
#
#                                email  matriculas
# id_aluno
# 31        luis@dominiodoemail.com.br           3
# 33         rafael@servicodoemail.com           4

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))["nome"]
# Out:
# id_aluno
# 31      LUIS
# 33    RAFAEL
# Name: nome, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))["nome"].to_frame()
# Out:
#             nome
# id_aluno
# 31          LUIS
# 33        RAFAEL

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# nome_do_curso    Cursos de Python
# Name: 5, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Cursos de Python'

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))["nome"].to_frame()

# %%
proxima_turma = proxima_turma.rename(columns = {'nome' : 'Alunos do curso de {}'.format(nome_curso)})
proxima_turma
# Out:
#          Alunos do curso de Cursos de Python
# id_aluno
# 31                                      LUIS
# 33                                    RAFAEL

# %% [markdown]
# # Exportar para Excel

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index = False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#   Alunos do curso de Cursos de Python
# 0                                LUIS
# 1                              RAFAEL
