# %% [markdown]
# # Relatório de Análises VI

# %% [markdown]
# ## Criando Novas Variáveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=";")

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 4       301.0  17.0

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados['Valor Bruto']
# Out:
# 0        2260.0
# 1        7000.0
# 2        1210.0
# 3        1030.0
# 4        1618.0
#           ...
# 21821    1438.0
# 21822    1175.0
# 21823    2640.0
# 21824    1946.0
# 21825    3760.0
# Name: Valor Bruto, Length: 21826, dtype: float64

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto
# 0       500.0  60.0       2260.0
# 1         0.0   0.0       7000.0
# 2       390.0  20.0       1210.0
# 3       230.0   0.0       1030.0
# 4       301.0  17.0       1618.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto   Valor m2
# 0       500.0  60.0       2260.0  42.500000
# 1         0.0   0.0       7000.0  70.000000
# 2       390.0  20.0       1210.0  53.333333
# 3       230.0   0.0       1030.0  16.666667
# 4       301.0  17.0       1618.0  26.000000

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2
# 0       500.0  60.0       2260.0     42.50
# 1         0.0   0.0       7000.0     70.00
# 2       390.0  20.0       1210.0     53.33
# 3       230.0   0.0       1030.0     16.67
# 4       301.0  17.0       1618.0     26.00

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Valor m2']).round(2)

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0   1700.0       500.0  60.0       2260.0     42.50           53.18
# 1   7000.0         0.0   0.0       7000.0     70.00          100.00
# 2    800.0       390.0  20.0       1210.0     53.33           22.69
# 3    800.0       230.0   0.0       1030.0     16.67           61.79
# 4   1300.0       301.0  17.0       1618.0     26.00           62.23
# 5  22000.0         0.0   0.0      22000.0     29.33          750.09
# 6   1000.0         0.0   0.0       1000.0     15.38           65.02
# 7   1500.0       642.0  74.0       2216.0     21.43          103.41
# 8   1500.0       455.0  14.0       1969.0     16.67          118.12
# 9   2000.0       561.0  50.0       2611.0     50.00           52.22

# %%
casa = ['Casa','Casa de vila', 'Casa de Condomínio']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados.head(20)
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete               Copacabana        1      0       0    40
# 1                 Casa          Jardim Botânico        2      0       1   100
# 2          Apartamento                   Centro        1      0       0    15
# 3          Apartamento             Higienópolis        1      0       0    48
# 4          Apartamento                 Cachambi        2      0       0    50
# 5   Casa de Condomínio          Barra da Tijuca        5      4       5   750
# 6   Casa de Condomínio                    Ramos        2      2       0    65
# 7          Apartamento                   Grajaú        2      1       0    70
# 8          Apartamento      Lins de Vasconcelos        3      1       1    90
# 9          Apartamento               Copacabana        1      0       1    40
# 10           Quitinete               Copacabana        1      0       0    27
# 11         Apartamento               Copacabana        4      3       1   243
# 12  Casa de Condomínio                  Taquara        3      1       1   115
# 13         Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 14         Apartamento          Barra da Tijuca        2      1       1    67
# 15         Apartamento                   Tijuca        2      1       0   110
# 16  Casa de Condomínio          Barra da Tijuca        4      3       2   466
# 17         Apartamento                   Olaria        3      1       0    68
# 18         Apartamento                   Tijuca        2      1       0    78
# 19         Apartamento                  Ipanema        3      1       1   125
#
#       Valor  Condominio   IPTU  Valor Bruto  Valor m2  Valor Bruto m2  \
# 0    1700.0       500.0   60.0       2260.0     42.50           53.18
# 1    7000.0         0.0    0.0       7000.0     70.00          100.00
# 2     800.0       390.0   20.0       1210.0     53.33           22.69
# 3     800.0       230.0    0.0       1030.0     16.67           61.79
# 4    1300.0       301.0   17.0       1618.0     26.00           62.23
# 5   22000.0         0.0    0.0      22000.0     29.33          750.09
# 6    1000.0         0.0    0.0       1000.0     15.38           65.02
# 7    1500.0       642.0   74.0       2216.0     21.43          103.41
# 8    1500.0       455.0   14.0       1969.0     16.67          118.12
# 9    2000.0       561.0   50.0       2611.0     50.00           52.22
# 10   1800.0       501.0    0.0       2301.0     66.67           34.51
# 11  13000.0      2000.0  803.0      15803.0     53.50          295.38
# 12   2000.0         0.0    0.0       2000.0     17.39          115.01
# 13    950.0       300.0   28.0       1278.0     17.59           72.65
# 14   1700.0       589.0  147.0       2436.0     25.37           96.02
# 15   1900.0       700.0  138.0       2738.0     17.27          158.54
# 16   7500.0      2695.0    0.0      10195.0     16.09          633.62
# 17   1000.0       670.0    0.0       1670.0     14.71          113.53
# 18   2000.0       700.0    0.0       2700.0     25.64          105.30
# 19   7000.0      2100.0  463.0       9563.0     56.00          170.77
#
#    Tipo Agregado
# 0    Apartamento
# 1           Casa
# 2    Apartamento
# 3    Apartamento
# 4    Apartamento
# 5           Casa
# 6           Casa
# 7    Apartamento
# 8    Apartamento
# 9    Apartamento
# 10   Apartamento
# 11   Apartamento
# 12          Casa
# 13   Apartamento
# 14   Apartamento
# 15   Apartamento
# 16          Casa
# 17   Apartamento
# 18   Apartamento
# 19   Apartamento

# %% [markdown]
# ## Excluindo Variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto m2', 'Valor Bruto']])

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2  Valor Bruto
# 0       Apartamento     42.50           53.18       2260.0
# 1              Casa     70.00          100.00       7000.0
# 2       Apartamento     53.33           22.69       1210.0
# 3       Apartamento     16.67           61.79       1030.0
# 4       Apartamento     26.00           62.23       1618.0
# ...             ...       ...             ...          ...
# 21821   Apartamento     12.86          111.82       1438.0
# 21822   Apartamento     29.63           39.66       1175.0
# 21823   Apartamento     23.08          114.38       2640.0
# 21824   Apartamento     29.17           66.71       1946.0
# 21825   Apartamento     42.86           87.73       3760.0
#
# [21826 rows x 4 columns]

# %%
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto m2  Valor Bruto
# 0   Apartamento     42.50           53.18       2260.0
# 1          Casa     70.00          100.00       7000.0
# 2   Apartamento     53.33           22.69       1210.0
# 3   Apartamento     16.67           61.79       1030.0
# 4   Apartamento     26.00           62.23       1618.0

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2
# 0       Apartamento     42.50           53.18
# 1              Casa     70.00          100.00
# 2       Apartamento     53.33           22.69
# 3       Apartamento     16.67           61.79
# 4       Apartamento     26.00           62.23
# ...             ...       ...             ...
# 21821   Apartamento     12.86          111.82
# 21822   Apartamento     29.63           39.66
# 21823   Apartamento     23.08          114.38
# 21824   Apartamento     29.17           66.71
# 21825   Apartamento     42.86           87.73
#
# [21826 rows x 3 columns]

# %%
dados_aux.pop('Valor Bruto m2')
# Out:
# 0         53.18
# 1        100.00
# 2         22.69
# 3         61.79
# 4         62.23
#           ...
# 21821    111.82
# 21822     39.66
# 21823    114.38
# 21824     66.71
# 21825     87.73
# Name: Valor Bruto m2, Length: 21826, dtype: float64

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2
# 0       Apartamento     42.50
# 1              Casa     70.00
# 2       Apartamento     53.33
# 3       Apartamento     16.67
# 4       Apartamento     26.00
# ...             ...       ...
# 21821   Apartamento     12.86
# 21822   Apartamento     29.63
# 21823   Apartamento     23.08
# 21824   Apartamento     29.17
# 21825   Apartamento     42.86
#
# [21826 rows x 2 columns]

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace = True)

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep=";", index = False)
